# %%
import sys, os
# Get project root (the parent directory of "src")
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

from src.dag.dag import *  # now this will work

# %%
edges = [("A","B"), ("B","C"), ("A","C"), ("C","D"), ("x","B"), ("Z","C")]
dag = DAG(from_edges=edges)

print(dag.get_nodes())
print(dag._nodes_dict)

dag._graph.display()
dag._topologic_sort()
print(dag._topologic_sort())
dag._coparents
# Out:
#  > Getting nodes with sort method: str_sort
#  > Getting nodes with sort method: topologic_sort
# ['A', 'x', 'B', 'C', 'D']
# {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'x': 4}
#
#
#   ·
#  -1  ·
#  -1 -1  ·
#   0  0 -1  ·
#   0  1  0  0  ·
#
# ['A', 'x', 'B', 'C', 'D']
# defaultdict(set, {0: {1, 4}, 1: {0}, 4: {0}})

# %%
dag.markov_blanket("B")
# Out:
# {'A', 'C', 'x'}
