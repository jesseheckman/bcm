# %%
import sys, os
# Get project root (the parent directory of "src")
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

from src.dag.dag import *  # now this will work

# %%
dag = DAG()
mat = STAM(5)
mat.set_edge(4, 1, 2, "i_to_j")
mat.set_edge(2, 0, 3)
mat.display()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dag = DAG()
#       2 mat = STAM(5)
#       3 mat.set_edge(4, 1, 2, "i_to_j")
#
# NameError: name 'DAG' is not defined
