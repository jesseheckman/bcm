# %%
import sys, os
# Get project root (the parent directory of "src")
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

from src.dag.dag import *  # now this will work

# %%
edges = [("A","B"), ("B","C"), ("A","C"), ("C","D"), ("x","B")]
dag = DAG(from_edges=edges)

print(dag.get_nodes())
print(dag._nodes_dict)

dag._graph.display()
dag._topologic_sort()

dag._coparents
# Out:
#  > Adding edge in matrix: A=0 -> B=1
#  > Adding edge in matrix: B=1 -> C=2
#  > Adding edge in matrix: A=0 -> C=2
#  > Adding edge in matrix: C=2 -> D=3
#  > Adding edge in matrix: x=4 -> B=1
# ['A', 'B', 'C', 'D', 'x']
# {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'x': 4}
#
#
#   ·
#  -1  ·
#  -1 -1  ·
#   0  0 -1  ·
#   0  1  0  0  ·
# defaultdict(set, {0: {1, 4}, 1: {0}, 4: {0}})

# %%
# Out:
# defaultdict(set, {0: {1, 4}, 1: {0}, 4: {0}})
