# %%
import sys, os
# Get project root (the parent directory of "src")
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

from src.dag.dag import *  # now this will work

# %%
mat = STAM(5)
mat.set_edge(4, 1, 1, "i_to_j")
mat.set_edge(2, 0, 1, "j_to_i")
mat.display()
# Out:
#   ·
#   0  ·
#  -1  0  ·
#   0  0  0  ·
#   0  1  0  0  ·

# %%
edges = [("A","B"), ("B","C")]
dag = DAG(from_edges=edges)

dag._graph.display()

dag._nodes_dict
# Out:
# Nodes identified in graph: {'C', 'B', 'A'}
#   ·
#   1  ·
#   0  1  ·
# {'C': 0, 'B': 1, 'A': 2}
